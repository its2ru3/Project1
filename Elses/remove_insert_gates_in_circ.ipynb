# %%
from random_circuit_generator import *

# %%
# %%time
qm, qr= random_circ_d_const(25,100)
# qm.draw(fold=-1)
# gate_counts(qm)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 140 ms

# %%
# %%time
qm.data
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# [CircuitInstruction(operation=Instruction(name='cz', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 18), Qubit(QuantumRegister(25, 'q'), 22)), clbits=()), CircuitInstruction(operation=Instruction(name='z', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 14),), clbits=()), CircuitInstruction(operation=Instruction(name='h', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 24),), clbits=()), CircuitInstruction(operation=Instruction(name='h', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 16),), clbits=()), CircuitInstruction(operation=Instruction(name='z', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 19),), clbits=()), CircuitInstruction(operation=Instruction(name='h', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 2),), clbits=()), CircuitInstruction(operation=Instruction(name='h', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 5),), clbits=()), CircuitInstruction(operation=Instruction(name='cz', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 21), Qubit(QuantumRegister(25, 'q'), 7)), clbits=()), CircuitInstruction(operation=Instruction(name='z', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 11),), clbits=()), CircuitInstruction(operation=Instruction(name='ccz', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 4), Qubit(QuantumRegister(25, 'q'), 12), Qubit(QuantumRegister(25, 'q'), 23)), clbits=()), CircuitInstruction(operation=Instruction(name='z', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 10),), clbits=()), CircuitInstruction(operation=Instruction(name='cz', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 15), Qubit(QuantumRegister(25, 'q'), 8)), clbits=()), CircuitInstruction(operation=Instruction(name='z', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 0),), clbits=()), CircuitInstruction(operation=Instruction(name='cz', num_qubits=2, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 17), Qubit(QuantumRegister(25, 'q'), 6)), clbits=()), CircuitInstruction(operation=Instruction(name='z', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 13),), clbits=()), CircuitInstruction(operation=Instruction(name='ccz', num_qubits=3, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 9), Qubit(QuantumRegister(25, 'q'), 3), Qubit(QuantumRegister(25, 'q'), 1)), clbits=()), CircuitInstruction(operation=Instruction(name='z', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 20),), clbits=()), CircuitInstruction(operation=Instruction(name='barrier', num_qubits=25, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q'), 0), Qubit(QuantumRegister(25, 'q'), 1), Qubit(QuantumRegister(25, 'q'), 2), Qubit(QuantumRegister(25, 'q'), 3), Qubit(QuantumRegister(25, 'q'), 4), Qubit(QuantumRegister(25, 'q'), 5), Qubit(QuantumRegister(25, 'q'), 6), Qubit(QuantumRegister(25, 'q'), 7), Qubit(QuantumRegister(25, 'q'), 8), Qubit(QuantumRegister(25, 'q'), 9), Qubit(QuantumRegister(25, 'q'), 10), Qubit(QuantumRegister(25, 'q'), 11), Qubit(QuantumRegister(25, 'q'), 12), Qubit(QuantumRegister(25, 'q'), 13), Qubit(QuantumRegister(25, 'q'), 14), Qubit(QuantumRegister(25, 'q'), 15), Qubit(QuantumRegister(25, 'q'), 16), Qubit(QuantumRegister(25, 'q'), 17), Qubit(QuantumRegister(25, 'q'), 18), Qubit(QuantumRegister(25, 'q'), 19), Qubit(QuantumRegister(25, 'q'), 20), Qubit(QuantumRegister(25, 'q'), 21), Qubit(QuantumRegister(25, 'q'), 22), Qubit(QuantumRegister(25, 'q'), 23), Qubit(QuantumRegister(25, 'q'), 24)), clbits=()), CircuitInstruction(operation=Instruction(name='h', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(25, 'q ...

# %%
qm_data = [(instruction.operation.name, instruction.qubits) for instruction in qm.data]
for element in qm_data:
    print(element)
# Out:
# ('ccz', (Qubit(QuantumRegister(10, 'q'), 3), Qubit(QuantumRegister(10, 'q'), 4), Qubit(QuantumRegister(10, 'q'), 9)))
# ('cz', (Qubit(QuantumRegister(10, 'q'), 2), Qubit(QuantumRegister(10, 'q'), 5)))
# ('x', (Qubit(QuantumRegister(10, 'q'), 0),))
# ('ccz', (Qubit(QuantumRegister(10, 'q'), 6), Qubit(QuantumRegister(10, 'q'), 1), Qubit(QuantumRegister(10, 'q'), 8)))
# ('h', (Qubit(QuantumRegister(10, 'q'), 7),))
# ('barrier', (Qubit(QuantumRegister(10, 'q'), 0), Qubit(QuantumRegister(10, 'q'), 1), Qubit(QuantumRegister(10, 'q'), 2), Qubit(QuantumRegister(10, 'q'), 3), Qubit(QuantumRegister(10, 'q'), 4), Qubit(QuantumRegister(10, 'q'), 5), Qubit(QuantumRegister(10, 'q'), 6), Qubit(QuantumRegister(10, 'q'), 7), Qubit(QuantumRegister(10, 'q'), 8), Qubit(QuantumRegister(10, 'q'), 9)))
# ('h', (Qubit(QuantumRegister(10, 'q'), 5),))
# ('h', (Qubit(QuantumRegister(10, 'q'), 9),))
# ('h', (Qubit(QuantumRegister(10, 'q'), 4),))
# ('cz', (Qubit(QuantumRegister(10, 'q'), 6), Qubit(QuantumRegister(10, 'q'), 0)))
# ('ccz', (Qubit(QuantumRegister(10, 'q'), 3), Qubit(QuantumRegister(10, 'q'), 1), Qubit(QuantumRegister(10, 'q'), 7)))
# ('cz', (Qubit(QuantumRegister(10, 'q'), 8), Qubit(QuantumRegister(10, 'q'), 2)))
# ('barrier', (Qubit(QuantumRegister(10, 'q'), 0), Qubit(QuantumRegister(10, 'q'), 1), Qubit(QuantumRegister(10, 'q'), 2), Qubit(QuantumRegister(10, 'q'), 3), Qubit(QuantumRegister(10, 'q'), 4), Qubit(QuantumRegister(10, 'q'), 5), Qubit(QuantumRegister(10, 'q'), 6), Qubit(QuantumRegister(10, 'q'), 7), Qubit(QuantumRegister(10, 'q'), 8), Qubit(QuantumRegister(10, 'q'), 9)))
# ('cz', (Qubit(QuantumRegister(10, 'q'), 3), Qubit(QuantumRegister(10, 'q'), 9)))
# ('x', (Qubit(QuantumRegister(10, 'q'), 2),))
# ('ccz', (Qubit(QuantumRegister(10, 'q'), 7), Qubit(QuantumRegister(10, 'q'), 1), Qubit(QuantumRegister(10, 'q'), 0)))
# ('ccz', (Qubit(QuantumRegister(10, 'q'), 5), Qubit(QuantumRegister(10, 'q'), 8), Qubit(QuantumRegister(10, 'q'), 4)))
# ('h', (Qubit(QuantumRegister(10, 'q'), 6),))
# ('barrier', (Qubit(QuantumRegister(10, 'q'), 0), Qubit(QuantumRegister(10, 'q'), 1), Qubit(QuantumRegister(10, 'q'), 2), Qubit(QuantumRegister(10, 'q'), 3), Qubit(QuantumRegister(10, 'q'), 4), Qubit(QuantumRegister(10, 'q'), 5), Qubit(QuantumRegister(10, 'q'), 6), Qubit(QuantumRegister(10, 'q'), 7), Qubit(QuantumRegister(10, 'q'), 8), Qubit(QuantumRegister(10, 'q'), 9)))
# ('h', (Qubit(QuantumRegister(10, 'q'), 9),))
# ('h', (Qubit(QuantumRegister(10, 'q'), 1),))
# ('ccz', (Qubit(QuantumRegister(10, 'q'), 2), Qubit(QuantumRegister(10, 'q'), 8), Qubit(QuantumRegister(10, 'q'), 7)))
# ('ccz', (Qubit(QuantumRegister(10, 'q'), 4), Qubit(QuantumRegister(10, 'q'), 0), Qubit(QuantumRegister(10, 'q'), 3)))
# ('h', (Qubit(QuantumRegister(10, 'q'), 5),))
# ('x', (Qubit(QuantumRegister(10, 'q'), 6),))
# ('barrier', (Qubit(QuantumRegister(10, 'q'), 0), Qubit(QuantumRegister(10, 'q'), 1), Qubit(QuantumRegister(10, 'q'), 2), Qubit(QuantumRegister(10, 'q'), 3), Qubit(QuantumRegister(10, 'q'), 4), Qubit(QuantumRegister(10, 'q'), 5), Qubit(QuantumRegister(10, 'q'), 6), Qubit(QuantumRegister(10, 'q'), 7), Qubit(QuantumRegister(10, 'q'), 8), Qubit(QuantumRegister(10, 'q'), 9)))
# ('x', (Qubit(QuantumRegister(10, 'q'), 8),))
# ('ccz', (Qubit(QuantumRegister(10, 'q'), 4), Qubit(QuantumRegister(10, 'q'), 3), Qubit(QuantumRegister(10, 'q'), 6)))
# ('cz', (Qubit(QuantumRegister(10, 'q'), 0), Qubit(QuantumRegister(10, 'q'), 5)))
# ('h', (Qubit(QuantumRegister(10, 'q'), 9),))
# ('ccz', (Qubit(QuantumRegister(10, 'q'), 2), Qubit(QuantumRegister(10, 'q'), 7), Qubit(QuantumRegister(10, 'q'), 1)))
# ('barrier', (Qubit(QuantumRegister(10, 'q'), 0), Qubit(QuantumRegister(10, 'q'), 1), Qubit(QuantumRegister(10, 'q'), 2), Qubit(QuantumRegister(10, 'q'), 3), Qubit(QuantumRegister(10, 'q'), 4), Qubit(QuantumRegister(10, 'q'), 5), Qubit(QuantumRegister(10, 'q'), 6), Qubit(QuantumRegister(10, 'q'), 7), Qubit(QuantumRegister(10, 'q'), 8), Qubit(QuantumRegister(10, 'q'), 9)))

# %%
# qm.data.append("CircuitInstruction(operation=Instruction(name='z', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(10, 'q'), 4),), clbits=())")
# qr = qm.qregs[0]
z_gate =  HGate()
qm.data.remove(1, (z_gate, [qr[0]], []))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 # qm.data.append("CircuitInstruction(operation=Instruction(name='z', num_qubits=1, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(10, 'q'), 4),), clbits=())")
#       2 # qr = qm.qregs[0]
#       3 z_gate =  HGate()
# ----> 4 qm.data.remove(1, (z_gate, [qr[0]], []))
#
# TypeError: MutableSequence.remove() takes 2 positional arguments but 3 were given

# %%
from qiskit import QuantumCircuit, QuantumRegister
from qiskit.circuit.library import ZGate

# Create a quantum register and a quantum circuit
qr = QuantumRegister(5, 'q')
qc = QuantumCircuit(qr)

# Add initial gates
qc.h(qr[0])
qc.cx(qr[0], qr[1])

qc.draw()
# Create a Z gate
z_gate = ZGate()

# Insert the Z gate between the H and CX gates
qc.data.insert(1, (z_gate, [qr[0]], []))  # (operation, qargs, cargs)

# Print the modified circuit
qc.draw()
# Out:
#      ┌───┐┌───┐
# q_0: ┤ H ├┤ Z ├──■──
#      └───┘└───┘┌─┴─┐
# q_1: ──────────┤ X ├
#                └───┘
# q_2: ───────────────
#
# q_3: ───────────────
#
# q_4: ───────────────

# %%
from qiskit import QuantumCircuit, QuantumRegister
from qiskit.circuit.library import HGate, ZGate, XGate, CZGate

# Create a quantum register and a quantum circuit
qr = QuantumRegister(5, 'q')
qc = QuantumCircuit(qr)

# Add some gates to the circuit
qc.h(qr[0])
qc.cz(qr[0], qr[1])
qc.z(qr[4])
qc.x(qr[2])
qc.cz(qr[1], qr[3])

# Print the initial circuit
print("Initial Circuit:")
print(qc)

# Define a function to remove a gate from the circuit based on its type and qubits
def remove_gate(qc, gate_type, qubits):
    qc.data = [
        instr for instr in qc.data 
        if not (instr[0].name == gate_type and [qb.index for qb in instr[1]] == qubits)
    ]

# Modify the function to properly access qubit indices
def remove_gate(qc, gate_type, qubit_indices):
    def get_qubit_index(qubit):
        return qr.index(qubit)
    
    qc.data = [
        instr for instr in qc.data 
        if not (instr[0].name == gate_type and [get_qubit_index(qb) for qb in instr[1]] == qubit_indices)
    ]

# Remove the Z gate on qubit 4
remove_gate(qc, 'x', [2])

# Print the modified circuit
print("\nModified Circuit:")
print(qc)
# Out:
# Initial Circuit:
#      ┌───┐
# q_0: ┤ H ├─■────
#      └───┘ │
# q_1: ──────■──■─
#      ┌───┐    │
# q_2: ┤ X ├────┼─
#      └───┘    │
# q_3: ─────────■─
#      ┌───┐
# q_4: ┤ Z ├──────
#      └───┘
#
# Modified Circuit:
#      ┌───┐
# q_0: ┤ H ├─■────
#      └───┘ │
# q_1: ──────■──■─
#               │
# q_2: ─────────┼─
#               │
# q_3: ─────────■─
#      ┌───┐
# q_4: ┤ Z ├──────
#      └───┘
