# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('Results\\run2\\arbitrary_h\\program_data_h.csv')
data.head()
# Out:
#    n  h    d    g  t  h_prob  cpu_time_poly  wall_time_poly  cpu_time_ddsim  \
# 0  3  1    8   10  4    0.05           0.00        0.000179             0.0
# 1  3  2   53   86  5    0.05           0.00        0.000593             0.0
# 2  3  3   50   82  6    0.05           0.00        0.000897             0.0
# 3  3  4   51   75  7    0.05           0.00        0.001433             0.0
# 4  3  5  136  205  8    0.05           0.01        0.007046             0.0
#
#    wall_time_ddsim  cpu_time_aer  wall_time_aer
# 0         0.002051           0.0       0.001225
# 1         0.001977           0.0       0.002319
# 2         0.001884           0.0       0.002306
# 3         0.001867           0.0       0.002294
# 4         0.002481           0.0       0.004090

# %%
fig, ax1 = plt.subplots()

# Plot CPU and wall time for poly, ddsim, and aer with points
ax1.scatter(data['h'], data['cpu_time_poly'], color='blue', label='CPU Time Poly', marker='o')
ax1.scatter(data['h'], data['wall_time_poly'], color='blue', label='Wall Time Poly', marker='x')
ax1.scatter(data['h'], data['cpu_time_ddsim'], color='red', label='CPU Time DDSIM', marker='o')
ax1.scatter(data['h'], data['wall_time_ddsim'], color='red', label='Wall Time DDSIM', marker='x')
ax1.scatter(data['h'], data['cpu_time_aer'], color='green', label='CPU Time Aer', marker='o')
ax1.scatter(data['h'], data['wall_time_aer'], color='green', label='Wall Time Aer', marker='x')

# Set labels for the axes
ax1.set_xlabel('h')
ax1.set_ylabel('Time (s)')
ax1.set_title('Comparison of CPU and Wall Time')

# Create another y-axis for the value of n
ax2 = ax1.twinx()
ax2.plot(data['h'], data['n'], color='purple', label='Value of n', linestyle='dotted')
ax2.set_ylabel('Value of n')

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show plot
plt.show()

# %%
fig, ax1 = plt.subplots()

# Plot CPU time for poly, ddsim, and aer with points
ax1.scatter(data['h'], data['cpu_time_poly'], color='blue', label='CPU Time Poly', marker='o')
ax1.scatter(data['h'], data['cpu_time_ddsim'], color='red', label='CPU Time DDSIM', marker='o')
ax1.scatter(data['h'], data['cpu_time_aer'], color='green', label='CPU Time Aer', marker='o')

# Set labels for the axes
ax1.set_xlabel('h')
ax1.set_ylabel('CPU Time (s)')
ax1.set_title('Comparison of CPU Time')

# Create another y-axis for the value of n
ax2 = ax1.twinx()
ax2.plot(data['h'], data['n'], color='purple', label='Value of n', linestyle='dotted')
ax2.set_ylabel('Value of n')

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show plot
plt.show()

# Create a figure and axis for Wall time
fig, ax3 = plt.subplots()

# Plot Wall time for poly, ddsim, and aer with points
ax3.scatter(data['h'], data['wall_time_poly'], color='blue', label='Wall Time Poly', marker='x')
ax3.scatter(data['h'], data['wall_time_ddsim'], color='red', label='Wall Time DDSIM', marker='x')
ax3.scatter(data['h'], data['wall_time_aer'], color='green', label='Wall Time Aer', marker='x')

# Set labels for the axes
ax3.set_xlabel('h')
ax3.set_ylabel('Wall Time (s)')
ax3.set_title('Comparison of Wall Time')

# Create another y-axis for the value of n
ax4 = ax3.twinx()
# ax4.plot(data['h'], data['n'], color='purple', label='Value of n')
ax4.set_ylabel('Value of n')

# Add legends
ax3.legend(loc='upper left')
ax4.legend(loc='upper right')

# Show plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from mpl_toolkits.mplot3d import Axes3D


# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot CPU time for poly, ddsim, and aer with points
ax.scatter(data['h'], data['n'], data['cpu_time_poly'], color='blue', label='CPU Time Poly', marker='o')
ax.scatter(data['h'], data['n'], data['cpu_time_ddsim'], color='red', label='CPU Time DDSIM', marker='o')
ax.scatter(data['h'], data['n'], data['cpu_time_aer'], color='green', label='CPU Time Aer', marker='o')

# Set labels for the axes
ax.set_xlabel('h')
ax.set_ylabel('n')
ax.set_zlabel('CPU Time (s)')
ax.set_title('Comparison of CPU Time in 3D')

# Add legend
ax.legend()

# Show plot
plt.show()
